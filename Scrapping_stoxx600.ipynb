# %%
import requests
from bs4 import BeautifulSoup, NavigableString, Tag
import re
import pandas as pd
import numpy as np
import json

# %%
from lxml.html import fromstring
import requests
from itertools import cycle
import traceback
import yfinance as yf

def get_proxies(n_proxies):
    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    parser = fromstring(response.text)
    proxies = []
    for i in parser.xpath('//tbody/tr')[:n_proxies]:
        if i.xpath('.//td[7][contains(text(),"yes")]'):
            proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
            proxies.append(proxy)
    return proxies


def proxy_get(url, n_proxies=100):
    proxies = get_proxies(n_proxies)
    proxy_pool = cycle(set(proxies))
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    for i in range(1, n_proxies+1):
        # Get a proxy from the pool
        proxy = next(proxy_pool)
        # print("Request #%d" % i)
        try:
            response = requests.get(url, proxies={"http": proxy, "https": proxy}, headers=headers)
            return response
        except Exception as e:
            pass
    return requests.get(url)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
## First we need components of the Stoxx600
## however there seems to be no available list of tickers 
## instead we need to find the name => ticker =>download historical data

## This is the first approach, which yields 136 tickers, 
## please skip to cell 9 for the final approach of 412 tickers

## investing.com has names of the company, and each has a href which leads to ticker/ symbol
html_index = r"https://uk.investing.com/indices/stoxx-600-components"
r = proxy_get(html_index)
index_soup = BeautifulSoup(r.text, 'html.parser')

names_list = set()
href_list = set()
for trs in index_soup.find_all('tbody'):
    for a in trs.find_all('a'):
        if 'equities' in a['href']:
            names_list.add(*a.contents)
            href_list.add(a['href'])

# %%
len(names_list)
# Out:
# 612

# %%
with open("stoxx600_component_names.txt", "w") as text_file:
    text_file.write(",".join(names_list))

# %%
## join with a file that supposed to have all yahoo finance stock tickers
## seems the list is a bit short 
names2ticker = pd.read_csv("name2ticker.csv", encoding='ISO-8859-1')
europe_countries = ["Albania","Andorra","Armenia","Austria","Azerbaijan","Belarus","Belgium","Bosnia and Herzegovina","Bulgaria","Croatia","Cyprus","Czech Republic","Denmark","Estonia","Finland","France","Georgia","Germany","Greece","Hungary","Iceland","Ireland","Italy","Kazakhstan","Latvia","Liechtenstein","Lithuania","Luxembourg","Macedonia","Malta","Moldova","Monaco","Montenegro","Netherlands","Norway","Poland","Portugal","Romania","Russia","San Marino","Serbia","Slovakia","Slovenia","Spain","Sweden","Switzerland","Turkey","Ukraine","United Kingdom","Vatican City"]
names2ticker.loc[(names2ticker['Name'].isin(names_list))&(names2ticker['Country'].isin(europe_countries))]
# Out:
#         Ticker           Name Exchange               Category Name  \
# 974     WDI.DE    Wirecard AG      GER           Business Services
# 995      MT.AS  ArcelorMittal      AMS                Steel & Iron
# 1329   SAND.ST     Sandvik AB      STO       Diversified Machinery
# 1860   ARRB.DE  ArcelorMittal      GER                         NaN
# 3205     BN.PA         Danone      PAR    Food - Major Diversified
# ...        ...            ...      ...                         ...
# 69262  SANF.MI         Sanofi      MIL  Drug Manufacturers - Major
# 69471    ML.SW       Michelin      EBS                         NaN
# 69610   RUI.PA          Rubis      PAR               Gas Utilities
# 69666   FRA.SW     Fraport AG      EBS                         NaN
# 69903  FTE1.DE         Orange      GER                         NaN
#
#            Country
# 974        Germany
# 995    Netherlands
# 1329        Sweden
# 1860       Germany
# 3205        France
# ...            ...
# 69262        Italy
# 69471  Switzerland
# 69610       France
# 69666  Switzerland
# 69903      Germany
#
# [136 rows x 5 columns]

# %%
## we'll save this for now, let see if we can get ticker by going to each href link
fornow_li_stoxx600 = names2ticker.loc[(names2ticker['Name'].isin(names_list))&(names2ticker['Country'].isin(europe_countries))]['Ticker'].tolist()

# %% [markdown]
# ## Change from MD to Code to run,
#
# ## rather than joining to the file, we can go to each href and obtain ticker,
# ## would need proxies and investing.com bans traffic even with headers/ low request frequency
# ## this found to be very slow, due to free proxies
#
# new_new_li_yhoo_tickers = []
# headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
# for href in href_links[::-1]:
#     url_ticker = f"https://www.investing.com{href}"
#     r = proxy_get(url_ticker)
#     ticker_index_soup = BeautifulSoup(r.text, 'html.parser')
#     for sth in ticker_index_soup.find_all("div", {"class":"instrumentHead"}):
#         for sth_else in sth.find_all("h1"):
#             t = sth_else.contents[0]
#             ticker = re.search(r'\((.*?)\)',t).group(1)
#             # print(re.search(r"\[([A-Za-z0-9_]+)\]", t))
#         for exchange in sth.find_all("div", {"class":"exchangeDropdownContainer"}):
#             location = exchange.find("i").contents[0]
#     try:
#         ex_suffix = city2ticker.loc[(city2ticker['Market'].str.contains(location))|(city2ticker['City'].str.contains(location))|(city2ticker['Country'].str.contains(location))].head(1)['Suffix'].values[0]
#         print(f"{ticker}{ex_suffix}")
#
#
#         new_new_li_yhoo_tickers.append(f"{ticker}{ex_suffix}")
#
#
#     except:
#
#         print(f"fail {ticker} {location}")

# %%
## The successful method
## finding out hidden deep in stoxx website, a list of component companies name
## New approach would be search for autocomplete from yahoo finance then download with ticker
company_names = pd.read_csv('SXXGR.csv')
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
tickers = []
for name in company_names['Company'].tolist():
    yhoo_url = f"http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={name}&region=1&lang=en&callback=YAHOO.Finance.SymbolSuggest.ssCallback"
    r = requests.get(yhoo_url, headers=headers)
    try:
        ticker = [x for x in json.loads(re.search(r'\((.*?)\)',r.text).group(1))['ResultSet']['Result'] if x['exch']!='PNK' and x['exchDisp']!='OTC Markets' and x['exchDisp']!='NYSE' ]
        print(f"{name}: {ticker[0]['symbol']}")
        tickers.append(ticker[0]['symbol'])
    except Exception as e:
        print(f"fail {name}")
# Out:
# NESTLE: NESM.KL
# fail ROCHE HLDG P
# NOVARTIS: 0QLR.IL
# ASML HLDG: ASML
# SAP: SPNS
# ASTRAZENECA: AZN.L
# SANOFI: SNY
# fail NOVO NORDISK B
# fail LINDE
# LVMH MOET HENNESSY: 0HAU.IL
# TOTAL: TOT.TI
# GLAXOSMITHKLINE: GSK.L
# HSBC: HSOAX
# SIEMENS: SIE.DE
# BRITISH AMERICAN TOBACCO: BTIIX
# ALLIANZ: ALV.TI
# DIAGEO: DGE.L
# BP: BPY
# UNILEVER NV: UAL
# BAYER: BMW.DE
# fail L'OREAL
# ROYAL DUTCH SHELL A: R6C.HM
# AIR LIQUIDE: 0NWF.IL
# IBERDROLA: IBE1.SG
# UNILEVER PLC: ULTA
# ENEL: ENEL.MI
# fail RECKITT BENCKISER GRP
# RIO TINTO: RIOT
# SCHNEIDER ELECTRIC: SCHN.TI
# DEUTSCHE TELEKOM: 0MPH.IL
# VINCI: DG.PA
# BASF: BASF.TI
# ZURICH INSURANCE GROUP: ZFIN.SG
# ADIDAS: ADSG-U.TI
# DANONE: BSN.HM
# fail RELX PLC
# BNP PARIBAS: ^BNPIC52T
# AIRBUS: AIR.BE
# ANHEUSER-BUSCH INBEV: 1NBA.HA
# AXA: AXA.TI
# Kering: KER.PA
# VODAFONE GRP: VOD
# NATIONAL GRID: NGG22.NYM
# fail BHP GROUP PLC.
# PHILIPS: PHIA.TI
# fail BCO SANTANDER
# Prosus: PRX.AS
# ESSILORLUXOTTICA: ESL.SG
# fail UBS GROUP
# PRUDENTIAL: PBIP
# ABB: LALDX
# LONZA: LONN.SW
# SAFRAN: SAF.PA
# MUENCHENER RUECK: MUV2.SG
# ADYEN: ADYEN.AS
# DAIMLER: DCX.TI
# DEUTSCHE POST: DPW.SG
# fail CIE FINANCIERE RICHEMONT
# DEUTSCHE BOERSE: DB1GN.TI
# PERNOD RICARD: RI.PA
# LONDON STOCK EXCHANGE: LS4C.MU
# EXPERIAN: EXPN.L
# Industria de Diseno Textil SA: 0QWI.IL
# Vonovia SE: VNA.DE
# INTESA SANPAOLO: ISPRX
# ALCON: ALC.SW
# HERMES INTERNATIONAL: FGFAX
# GIVAUDAN: GIVN.SW
# AHOLD DELHAIZE: AD.AS
# INFINEON TECHNOLOGIES: IFX.SG
# fail CRH
# fail KONE B
# fail LLOYDS BANKING GRP
# fail ERICSSON LM B
# ANGLO AMERICAN: AAL.L
# TESCO: TSCO.L
# fail ING GRP
# ATLAS COPCO A: ACO2.DU
# VOLKSWAGEN PREF: VOW3-U.TI
# fail VOLVO B
# E.ON: EOA.TI
# ENI: ENIAX
# SIKA: SIKA.SW
# fail CREDIT SUISSE GRP
# NOKIA: NOKIA.HE
# KONINKLIJKE DSM: DSM.AS
# DSV Panalpina: DSV.CO
# AMADEUS IT GROUP: AI3A.SG
# fail INVESTOR B
# fail DASSAULT SYSTEMS
# BARCLAYS: BIL
# ENGIE: ENGI.PA
# ORANGE: FTE.SG
# COMPASS GRP: CFICOF3P-E.SN
# fail BCO BILBAO VIZCAYA ARGENTARIA
# fail GLENCORE PLC
# HEINEKEN: HEIA.AS
# TELEFONICA: TEF.TI
# NORDEA BANK: NDA-FI.HE
# fail SWISS REINSURANCE COMPANY
# VIVENDI: VIV.PA
# LafargeHolcim: LHN.SW
# RWE: RWE.TI
# WOLTERS KLUWER: WKL.AS
# FRESENIUS: FRE.TI
# FERRARI: RACE.MI
# UNICREDIT: CRIN.DE
# GENMAB: GMAB
# BMW: BMW.TI
# fail Essity B
# ORSTED: ORSTED.CO
# FLUTTER ENTERTAINMENT: FLTR.L
# fail ASSA ABLOY
# BAE SYSTEMS: BA.L
# VESTAS WIND SYSTEMS: VWS.CO
# ASSICURAZIONI GENERALI: G.MI
# LEGRAND: LR.PA
# DEUTSCHE BANK: DBX
# COLOPLAST B: 0QBO.IL
# KERRY GRP: KRZ.BE
# fail SAINT GOBAIN
# fail CAP GEMINI
# FERGUSON PLC: 24W5.BE
# SANDVIK: SAND.ST
# fail GEBERIT
# IMPERIAL BRANDS: IMB.L
# AKZO NOBEL: AKZA.AS
# SMITH & NEPHEW: SMSI
# STMICROELECTRONICS: SGM.BE
# FRESENIUS MEDICAL CARE: FMSDX
# SCOTTISH & SOUTHERN ENERGY: SMT.L
# MICHELIN: ML.PA
# NESTE: NESTE.HE
# SAMPO: 1604.TW
# HENKEL PREF: HEN3.TI
# fail PARTNERS GRP HLDG
# LEGAL & GENERAL GRP: 3497.T
# EQUINOR: EQNR.OL
# HEXAGON B: 0GRX.IL
# UPM KYMMENE: RPL.MU
# fail SGS
# ASHTEAD GRP: 0LC.MU
# fail SVENSKA HANDELSBANKEN A
# fail KBC GRP
# CELLNEX TELECOM: 472.SG
# DEUTSCHE WOHNEN: 0OBQ.IL
# FERROVIAL: UFG.SG
# MERCK: MRK.DE
# OCADO: OCDO.L
# SYMRISE: SY1.BE
# UCB: UCBI
# DELIVERY HERO: 0RTC.IL
# STANDARD CHARTERED: STAN.L
# TELEPERFORMANCE: TEP.PA
# CARLSBERG B: 2836.KL
# fail GRP SOCIETE GENERALE
# AVIVA: VMSIX
# SWISSCOM: SWJ.SG
# fail SKANDINAVISKA ENSKILDA BK A
# REPSOL: REPA.BE
# fail BT GRP
# NOVOZYMES: NZYM-B.CO
# DNB: DNB.OL
# EDP ENERGIAS DE PORTUGAL: 0OF7.IL
# VEOLIA ENVIRONNEMENT: VVD.SG
# SEGRO: SGRO.L
# fail SWEDBANK
# fail HENNES & MAURITZ B
# SWISS LIFE HLDG: SLW1.F
# ZALANDO: ZAL.DE
# SONOVA: SOON.SW
# RENTOKIL INITIAL: RTO.L
# fail SWEDISH MATCH
# CREDIT AGRICOLE: ACA.TI
# fail JUST EAT TAKEAWAY.COM NV
# fail SARTORIUS PREF.
# BEIERSDORF: BEI.DE
# NN GROUP: NN.AS
# fail EQT
# fail SNAM RETE GAS
# HALMA: HLMA.L
# fail INTERTEK GRP
# LOGITECH INTERNATIONAL: LOGI
# FIAT CHRYSLER AUTOMOBILES: FCAU.VI
# EDENRED: EDEN.PA
# WORLDLINE: WO6.BE
# fail CHR HANSEN HLDG
# CONTINENTAL: DFCSX
# HANNOVER RUECK: HNR1.BE
# TERNA: TRN.MI
# AENA SME: A44.F
# fail 3I GROUP PLC.
# TELENOR: TELO.OL
# WPP: WPP.L
# KINGSPAN GRP: KRX.BE
# TEMENOS: TE8N.SG
# QIAGEN: QGEN
# UMICORE: UMI.BR
# SCHINDLER P: SCHP.S
# MTU AERO ENGINES: MTX.SG
# SAGE GRP: SGK1.MU
# BOUYGUES: EN.PA
# JULIUS BAER GRP: JGE1.BE
# STRAUMANN: STMN.SW
# LEG IMMOBILIEN: LEG.HM
# fail ARGENX
# KPN: KPN.AS
# fail INTERCONTINENTAL HOTELS GRP
# fail TELIA COMPANY
# GRIFOLS: GRF-P.MC
# LINDT & SPRUENGLI REG: LISN.SW
# PERSIMMON: LSEIX
# ALSTOM: ALO.PA
# DANSKE BANK: DANSKE.CO
# CARREFOUR: CA.PA
# SPIRAX-SARCO: SPX.L
# KUEHNE + NAGEL: KNIU.BE
# EIFFAGE: FGR.PA
# GALAPAGOS: GLPG
# ASSOCIATED BRITISH FOODS: ABF.L
# fail ELISA CORPORATION
# fail PORSCHE PREF
# INGENICO: ING.PA
# BUNZL: BNZL.L
# fail GRP BRUXELLES LAMBERT
# fail MONDI
# THALES: CSF.BE
# FORTUM: FORTUM.HE
# HEINEKEN HLDG: 4H5.BE
# fail DCC
# NEXT: NEXT
# PEUGEOT: PEUP-U.TI
# CRODA INTERNATIONAL: CRDA.L
# UNIBAIL-RODAMCO-WESTFIELD: URW.AS
# MOWI: MOWIX
# SCOUT24: G24.HA
# fail RED ELECTRICA CORPORATION
# FINECOBANK: FBK.MI
# UNITED UTILITIES GRP: UUEC.BE
# BRENNTAG: BNRA.F
# ATOS: ATOS
# HEIDELBERGCEMENT: HEI.BE
# SKANSKA B: 0HBT.IL
# ROLLS ROYCE HLDG: RRU.MU
# BURBERRY: BRBY.L
# ENDESA: ENA.SG
# MONCLER: MONC.MI
# UBISOFT ENTERTAINMENT: UBI.PA
# fail EPIROC A
# ADECCO: ADEN.SW
# fail EVOLUTION GAMING GROUP
# CAIXABANK: 48CA.BE
# SEVERN TRENT: STRNX
# STORA ENSO R: ENUS.BE
# INFORMA: VGT
# ATLANTIA: ATL.MI
# fail A.P.MOLLER-MAERSK B
# NIBE INDUSTRIER B: NJBC.MU
# EUROFINS SCIENTIFIC: ERF.PA
# STANDARD LIFE ABERDEEN: SLA.L
# SIEMENS HEALTHINEERS: SHL.SG
# fail AROUNDTOWN (FRA)
# fail SMURFIT KAPPA GRP
# PUBLICIS GRP: PU4.MU
# ACS: ACST
# BALOISE: C8HA.MU
# ERSTE GROUP BANK: EBO.SG
# SWISS PRIME SITE: SPSN.SW
# MELROSE INDUSTRIES: MRO.L
# GN STORE NORD: GN.CO
# RYANAIR: RYAAY
# fail SVENSKA CELLULOSA B
# CNH Industrial NV: CNHI.MI
# SKF B: 0NWX.IL
# fail ROYAL BANK OF SCOTLAND GRP
# ASM INTERNATIONAL: ASMI.JK
# VIFOR PHARMA: G2AA.SG
# fail ADMIRAL GRP
# ORKLA: ORKO.OL
# BERKELEY GRP HLDG: 42BA.HA
# ARCELORMITTAL: MT.AS
# AGEAS: FORA.TI
# fail CD PROJECT SA
# YARA: YAR.OL
# ARKEMA: V1S.SG
# HARGREAVES LANSDOWN: HL.L
# fail HELLOFRESH AG
# TELE2 B: 0QE6.IL
# Naturgy Energy Group: GAN.SG
# fail SMITHS GRP
# EXOR NV: 0RKY.IL
# BUREAU VERITAS: BVI.PA
# PUMA: PUM.TI
# BARRATT DEVELOPMENTS: BDEV.L
# fail RIGHTMOVE GRP
# ORPEA: ORP.PA
# fail ALFA LAVAL
# KINNEVIK B: IV6D.BE
# Getlink: GET.PA
# AUTO TRADER GROUP: AUTO.L
# fail ST.JAMES'S PLACE CAPITAL
# fail AMBU 'B'
# SODEXO: SJ7.SG
# PRYSMIAN: PRY.MI
# fail EMS-CHEMIE HLDG
# fail PENNON GRP
# GECINA: GFC.PA
# SOLVAY: SOLB.BR
# COVESTRO: 1COV.DU
# TAYLOR WIMPEY: TW.L
# GALP ENERGIA: GALP.LS
# SARTORIUS STEDIM BIOTECH: 56S1.SG
# fail BOLIDEN
# fail SWATCH BEARER
# WHITBREAD: WTB.L
# fail BIOMERIEUX
# ENAGAS: EG4.SG
# fail PHOENIX GROUP HDG.
# fail MORRISON (WILLIAM) SUPERMARK
# BARRY CALLEBAUT: BCLN.SG
# PEARSON: PSON.L
# ACCOR: AC.PA
# RANDSTAD: RAND.AS
# GVC HOLDINGS: GVC.L
# KINGFISHER: KGF.L
# ORION B: 0M2O.IL
# VALEO: FR.PA
# DS SMITH: SMDS.L
# fail RSA INSURANCE GRP
# POLYMETAL INTERNATIONAL: POLY.L
# EURONEXT: ^N100
# COCA-COLA HBC: C0Q.SG
# LAND SECURITIES: LAND.L
# AEGON: AGN.TI
# UNIPER: UN01.TI
# M&G: MSFT
# fail PKNORLEN
# RECORDATI: REC.MI
# JOHNSON MATTHEY: JMAT.L
# PKO BANK: P9O.BE
# PANDORA: PNDORA.CO
# NEXI SPA: 0NX5.IL
# EVONIK INDUSTRIES: EVK.SG
# fail KNORR BREMSE
# MEDIOBANCA: MB.MI
# IMCD: IMCDX
# RENAULT: RNO.PA
# DIASORIN: DIA.MI
# PSP SWISS PROPERTY: P7S.SG
# OMV: OMV.VI
# RUBIS: RUI.PA
# fail CLARIANT
# fail CASTELLUM
# fail GEA GRP
# VAT GROUP AG: VACN.SW
# SCHRODERS: SEMNX
# DIRECT LINE INSURANCE GROUP: DLG.L
# KLEPIERRE: KPR.SG
# AMUNDI: AMUN.PA
# BECHTLE: BC8.BE
# EDF: EDFAX
# INTERMEDIATE CAPITAL GRP: I2X2.SG
# LUNDIN ENERGY: LYV.F
# fail SUEZ ENVIRONNEMENT
# HOMESERVE: HSV.L
# SCOR: SCOR
# AMS AG: AMS.SW
# KESKO: KESKOB.HE
# fail BRITISH LAND COMPANY
# HIKMA PHARMACEUTICALS: HIK.L
# fail HOWDEN JOINERY GRP
# ANTOFAGASTA: ANTO.L
# UNITED INTERNET: UTDI.SG
# fail SWEDISH ORPHAN BIOVITRUM
# JERONIMO MARTINS: JEM.SG
# METSO: VLM.DU
# SIMCORP: SIM.CO
# POSTE ITALIANE: PST.MI
# fail SAINSBURY (J)
# fail COMMERZBANK
# TELECOM ITALIA: TLRY
# fail PZU GROUP
# LANXESS: LXS.DE
# fail ICA GRUPPEN
# fail LA FRANCAISE DES JEUX
# SECURITAS B: 0IAH.IL
# ASR NEDERLAND NV: 0RHS.IL
# DAVIDE CAMPARI: CPR.MI
# SOFINA: 8FS.BE
# WARTSILA: 0IKJ.IL
# GETINGE B: 0GZV.IL
# fail AVAST PLC
# ABN AMRO BANK: ABN.AS
# B&M EUROPEAN VALUE RETAIL: BMRA
# BELLWAY: BWY.L
# COVIVIO: COV.PA
# TATE & LYLE: TATE.L
# KOJAMO OYJ: KOJAMO.HE
# TOMRA SYSTEMS: TOMO.OL
# TEAMVIEWER AG: TMV.DE
# INDUSTRIVARDEN A: 0H13.IL
# fail MORPHOSYS
# fail FASTIGHETS BALDER B
# KION GROUP: 0QFU.IL
# SPECTRIS: SXS.L
# DERWENT LONDON: DLN.L
# NEMETSCHEK: NEM.DE
# ELECTROLUX B: ELX.BE
# HUHTAMAKI: PAPERPROD.NS
# NORSK HYDRO: NHYO.OL
# fail SEB
# RHEINMETALL: RHM.SG
# CARL ZEISS MEDITEC: AFX.SG
# fail IG GRP HLDG
# ELECTROCOMPONENTS: ECM.L
# VOPAK: VPK.AS
# ROYAL UNIBREW: RBREW.CO
# fail CONVATEC PLC
# TAG IMMOBILIEN AG: TEG.DE
# BELIMO HOLDING: B9H.SG
# TECAN: TECN.SW
# fail GALENICA SANTE AG
# TRAVIS PERKINS: TPK.L
# fail WDP
# fail FABEGE
# SIEMENS GAMESA: SGRE.VI
# ELIA GROUP: E4S.BE
# DECHRA PHARMACEUTICALS: DPH.L
# fail INDUTRADE
# GJENSIDIGE FORSIKRING: GJF.OL
# TECHNIPFMC: FTI.PA
# ITV: ITV.L
# JD SPORTS FASHION: JD.L
# fail ELEKTA B
# fail EVOTEC
# COFINIMMO: COFB.BR
# fail TRELLEBORG B
# SIG COMBIBLOC GROUP AG: SIGN.SW
# GEORG FISCHER: 0QP4.IL
# WEIR GRP: 42W.BE
# Valmet: VALMT.HE
# UNITE GROUP PLC: U1B.MU
# TRYG: TRYG.CO
# fail LUNDBERGFORETAGEN B
# IAG: IAGAX
# PROXIMUS: PROX.BR
# WIRECARD: WDI.SG
# AMPLIFON: AMP.MI
# AVEVA GRP: 4A91.BE
# IMI: IMIDX
# GAMES WORKSHOP: GAW.L
# fail HUSQVARNA B
# TENARIS: TW11.SG
# MERLIN PROPERTIES SOCIMI: MEQA.SG
# THYSSENKRUPP: TKA.MU
# BANKINTER: 0H7O.IL
# ADP: ADP
# HOLMEN B: 0XS9.IL
# CENTRICA: CNA.L
# HERA: HERAX
# fail AAK
# TRITAX BIG BOX REIT: BBOX.L
# ACKERMANS & VAN HAAREN: ACKB.BR
# fail HELVETIA HLDG
# BAKKAFROST: BAKKA.OL
# HISCOX: HSX.L
# ILIAD: IL2.BE
# fail TRAINLINE PLC
# IPSEN: I7G.MU
# MEGGITT: MGGT.L
# SIGNIFY: LIGHT.AS
# CEMBRA MONEY BANK: GEH.SG
# fail SWECO 'B'
# REMY COINTREAU: RMC.SG
# VERBUND: 0NR1.IL
# AALBERTS: AALB.AS
# KGHM: KGHA.F
# BE SEMICONDUCTOR: BESI.AS
# ROTORK: ROR.L
# fail QUILTER
# OLD MUTUAL: OMU.JO
# fail ETS COLRUYT
# ITALGAS: IG.MI
# BOLLORE: 0IXZ.IL
# LEONARDO: LDO.MI
# SUNRISE: SRCG.SW
# NOKIAN RENKAAT: TYRES.HE
# DIALOG SEMICON: DLG.DE
# fail FUCHS PETROLUB PREF
# fail ALLREAL HLDG
# AEDIFICA: AED.BR
# ISS AS: QJQ.SG
# BEAZLEY: BEZ.L
# ANDRITZ: AZ2.SG
# CNP ASSURANCES: CNP.PA
# TELEFONICA DEUTSCHLAND: 0QAL.IL
# GENUS: GNS.L
# fail UBI BCA
# ALSTRIA OFFICE REIT: 0O9Q.IL
# LUFTHANSA: LHA.BE
# BRITVIC: BVIC.L
# fail DOMETIC GROUP AB
# SES: SESN
# REXEL: E7V.SG
# ALTICE EUROPE NV A: 6AT.BE
# fail SINCH
# FAURECIA: FAU.BE
# RAIFFEISEN BANK INTERNATIONAL: RBI.VI
# DIPLOMA: DPLM.L
# MARKS & SPENCER GRP: MKS.L
# fail SAMHALLSBYGGNADSBOL AGET NORD
# CTS EVENTIM: EVD.DE
# WENDEL: MF.PA
# ALTEN: AN3.SG
# GRAND CITY PROPERTIES: GYC.SG
# WIENERBERGER: WIB.BE
# SBM OFFSHORE: SBMO.AS
# EURAZEO: RF.PA
# TP ICAP: TCAP.L
# fail WIHLBORGS FASTIGHETER
# fail FLUGHAFEN ZURICH
# GLANBIA: GL9.IR
# MAN GRP: M3N.BE
# STOREBRAND: STBO.OL
# VOESTALPINE: VAS.SG
# PROSIEBENSAT.1 MEDIA: PSM.DE
# TUI: TUIFX
# INCHCAPE: INCH.L
# DEMANT: DEMANT.CO
# SALMAR: SALM.OL
# ASHMORE GRP: A1B.BE
# fail PEKAO
# INTERPUMP GRP: 8IG.F
# CARNIVAL: CVC1.SG
# fail INMOBILIARIA COLONIAL SOCIMI
# fail NETWORK INTERNATIONAL HOLDINGS
# IWG PLC: IWG.L
# H. LUNDBECK: LUN.CO
# ENTRA: ENTRA.OL
# A2A: A2A.MI
# fail UDG HEALTHCARE PUBLIC
# BANCO BPM: BAMI.MI
# HAYS: HAS.L
# NATIXIS: NBP.BE
# GREGGS: GRG.L
# LPP: LPPIX
# ICADE: ICAD.PA
# fail MONEYSUPERMARKET COM GP.
# ROYAL MAIL: RMG.L
# ELIS: ELISX
# RATIONAL: RTLLF
# VICTREX: VCT.L
# fail ACCIONA S.A.
# fail GRENKE N
# BANK OF IRELAND GROUP: BIRG.IR
# BAWAG GROUP AG: BG.VI
# DASSAULT AVIATION: AM.PA
# FREENET: FNTN.DU
# fail GRP 4 SECURICOR
# Signature Aviation: SIG.L
# fail SCHIBSTED GRUPPEN
# VISTRY GROUP: VTY.L
# fail BCO SABADELL
# AKER BP: AKERBP.OL
# SAAB B: 0GWL.IL
# fail CLOSE BROTHERS GRP
# fail HEXPOL 'B'
# SOPRA STERIA GROUP: SOP.PA
# SPIE: SPIE.PA
# EVRAZ: EVR.L
# MAPFRE: CMAB.BE
# EASYJET: EZJ.L
# MICRO FOCUS INTERNATIONAL: MCRO.L
# HOCHTIEF: HOT.DE
# fail LOOMIS B
# CHRISTIAN DIOR: CDI.PA
# TOPDANMARK: TOP.CO
# COUNTRYSIDE PROPERTIES PLC: 6CO.SG
# OSRAM LICHT: OSR.HA
# HUGO BOSS: BOSS.DU
# fail WOOD GRP (JOHN)
# TGS-NOPEC GEOPHYSICAL: TGSO.OL
# GREAT PORTLAND ESTATES: GPOR.L
# REDROW: RDW.L
# FRAPORT: 0O1R.IL
# METRO AG: B4B.DE
# IMMOFINANZ: IMO1.DE
# fail NEW WH SMITH
# EUTELSAT COMMUNICATION: ETL.PA
# SUBSEA7: BULL-SUBC-DNM.OL
# SSP GROUP: SSPG.L
# AGGREKO: AGK.L
# Virgin Money UK: VMUK.L
# SAIPEM: SPE1.BE
# SANTANDER BANK POLSKA: BZI.SG
# INVESTEC: INVR.L
# HAMMERSON: HMSO.L
# CINEWORLD GROUP: CINE.L
# fail CAPITA GRP
# fail DUFRY GRP

# %%
## filter out possible US companies, not within stoxx 600 based on it must have an . extension
tickers = [ticker for ticker in tickers if '.' in ticker]
print(len(tickers))
tickers_str = " ".join(tickers)
new_data = yf.download(tickers=tickers_str,period='max')
# Out:
# 412
# [*********************100%***********************]  412 of 412 completed
#
# 33 Failed downloads:
# - UN01.TI: 1d data not available for startTime=-2208988800 and endTime=1598279281. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - EOA.TI: 1d data not available for startTime=-2208988800 and endTime=1598279283. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - PUM.TI: 1d data not available for startTime=-2208988800 and endTime=1598279283. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - DCX.TI: 1d data not available for startTime=-2208988800 and endTime=1598279283. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - TELO.OL: 1d data not available for startTime=-2208988800 and endTime=1598279284. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - ORKO.OL: 1d data not available for startTime=-2208988800 and endTime=1598279284. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - FORA.TI: 1d data not available for startTime=-2208988800 and endTime=1598279285. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - AGN.TI: 1d data not available for startTime=-2208988800 and endTime=1598279286. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - TOMO.OL: 1d data not available for startTime=-2208988800 and endTime=1598279287. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - P9O.BE: 1d data not available for startTime=-2208988800 and endTime=1598279296. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - PEUP-U.TI: 1d data not available for startTime=-2208988800 and endTime=1598279298. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - ALV.TI: 1d data not available for startTime=-2208988800 and endTime=1598279298. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - AXA.TI: 1d data not available for startTime=-2208988800 and endTime=1598279298. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - STBO.OL: 1d data not available for startTime=-2208988800 and endTime=1598279299. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - VOW3-U.TI: 1d data not available for startTime=-2208988800 and endTime=1598279305. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - 24W5.BE: 1d data not available for startTime=-2208988800 and endTime=1598279311. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - DB1GN.TI: 1d data not available for startTime=-2208988800 and endTime=1598279311. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - CFICOF3P-E.SN: 1d data not available for startTime=-2208988800 and endTime=1598279313. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - SCHN.TI: 1d data not available for startTime=-2208988800 and endTime=1598279313. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - C8HA.MU: 1d data not available for startTime=-2208988800 and endTime=1598279313. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - TEF.TI: 1d data not available for startTime=-2208988800 and endTime=1598279314. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - NHYO.OL: 1d data not available for startTime=-2208988800 and endTime=1598279315. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - BASF.TI: 1d data not available for startTime=-2208988800 and endTime=1598279319. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - ADSG-U.TI: 1d data not available for startTime=-2208988800 and endTime=1598279325. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - ACA.TI: 1d data not available for startTime=-2208988800 and endTime=1598279326. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - PHIA.TI: 1d data not available for startTime=-2208988800 and endTime=1598279327. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - TOT.TI: 1d data not available for startTime=-2208988800 and endTime=1598279329. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - SCHP.S: 1d data not available for startTime=-2208988800 and endTime=1598279331. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - HEN3.TI: 1d data not available for startTime=-2208988800 and endTime=1598279334. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - TGSO.OL: 1d data not available for startTime=-2208988800 and endTime=1598279334. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - RWE.TI: 1d data not available for startTime=-2208988800 and endTime=1598279335. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - BMW.TI: 1d data not available for startTime=-2208988800 and endTime=1598279338. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - FRE.TI: 1d data not available for startTime=-2208988800 and endTime=1598279339. Only 100 years worth of day granularity data are allowed to be fetched per request.

# %%
new_data['Close']
# Out:
#                0GRX.IL     0GWL.IL     0GZV.IL     0H13.IL  0H7O.IL  \
# Date
# 1986-07-25         NaN         NaN         NaN         NaN      NaN
# 1986-07-28         NaN         NaN         NaN         NaN      NaN
# 1986-07-29         NaN         NaN         NaN         NaN      NaN
# 1986-07-30         NaN         NaN         NaN         NaN      NaN
# 1986-07-31         NaN         NaN         NaN         NaN      NaN
# ...                ...         ...         ...         ...      ...
# 2020-08-18  602.599976  274.500000  201.300003  230.199997   4.6230
# 2020-08-19  604.900024  274.750000  203.250000  230.800003   4.5925
# 2020-08-20  596.799988  273.500000  201.699997  232.199997   4.5825
# 2020-08-21  597.799988  271.350006  203.600006  228.699997   4.4250
# 2020-08-24  614.400024  274.100006  203.100006  233.600006   4.5090
#
#                0HAU.IL     0HBT.IL     0IAH.IL  0IKJ.IL  0IXZ.IL  ...  \
# Date                                                              ...
# 1986-07-25         NaN         NaN         NaN      NaN      NaN  ...
# 1986-07-28         NaN         NaN         NaN      NaN      NaN  ...
# 1986-07-29         NaN         NaN         NaN      NaN      NaN  ...
# 1986-07-30         NaN         NaN         NaN      NaN      NaN  ...
# 1986-07-31         NaN         NaN         NaN      NaN      NaN  ...
# ...                ...         ...         ...      ...      ...  ...
# 2020-08-18  384.825012  179.149994  127.025002    7.174    3.107  ...
# 2020-08-19  386.875000  178.375000  126.125000    7.154    3.161  ...
# 2020-08-20  383.549988  178.550003  124.199997    7.035    3.129  ...
# 2020-08-21  385.700012  177.149994  124.074997    7.023    3.132  ...
# 2020-08-24  393.549988  180.350006  126.800003    7.132    3.158  ...
#
#                 VWS.CO  WDI.SG     WIB.BE     WKL.AS     WO6.BE       WPP.L  \
# Date
# 1986-07-25         NaN     NaN        NaN        NaN        NaN         NaN
# 1986-07-28         NaN     NaN        NaN        NaN        NaN         NaN
# 1986-07-29         NaN     NaN        NaN        NaN        NaN         NaN
# 1986-07-30         NaN     NaN        NaN        NaN        NaN         NaN
# 1986-07-31         NaN     NaN        NaN        NaN        NaN         NaN
# ...                ...     ...        ...        ...        ...         ...
# 2020-08-18  926.000000  1.2502  21.799999  69.879997  73.059998  607.599976
# 2020-08-19  926.799988  1.3152  22.000000  70.580002  72.180000  613.400024
# 2020-08-20  917.400024  1.2856  21.559999  70.339996  72.120003  604.599976
# 2020-08-21  929.400024  1.2820  21.959999  70.879997  72.360001  602.400024
# 2020-08-24  954.599976  1.2590  22.820000  71.400002  72.580002  614.400024
#
#              WTB.L  YAR.OL     ZAL.DE     ZFIN.SG
# Date
# 1986-07-25     NaN     NaN        NaN         NaN
# 1986-07-28     NaN     NaN        NaN         NaN
# 1986-07-29     NaN     NaN        NaN         NaN
# 1986-07-30     NaN     NaN        NaN         NaN
# 1986-07-31     NaN     NaN        NaN         NaN
# ...            ...     ...        ...         ...
# 2020-08-18  2335.0   384.0  67.839996  305.100006
# 2020-08-19  2372.0   385.0  68.660004  305.100006
# 2020-08-20  2332.0   378.5  68.220001  305.100006
# 2020-08-21  2398.0   375.5  69.599998  305.100006
# 2020-08-24  2348.0   376.5  71.059998         NaN
#
# [8907 rows x 412 columns]

# %%
import types
def imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            yield val.__name__
list(imports())
# Out:
# ['builtins',
#  'builtins',
#  'requests',
#  're',
#  'pandas',
#  'numpy',
#  'json',
#  'traceback',
#  'yfinance',
#  'types']

# %%
new_data.dropna(how='all', axis=1, inplace=True)
new_data['Close'].to_pickle('new_close_stoxx600.pkl')

# %%
## Stoxx 600, index price
stoxx = yf.Ticker('^STOXX')
stoxx = stoxx.history(period="max")

stoxx.to_pickle('stoxx600.pkl')

# %%
yf.__version__
# Out:
# '0.1.54'
